# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 873.6/873.6 kB 6.8 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/yolov8/dataset
# Out:
# data.yaml  images  labels  test_img_1.jpg

# %%
from ultralytics import YOLO

# Load the YOLOv8 model (pretrained yolov8n.pt weights)
model = YOLO('yolov8n.pt')

# Train the model
model.train(data='/content/drive/MyDrive/yolov8/dataset/data.yaml', epochs=20, imgsz=640)
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 22.8MB/s]
# Ultralytics YOLOv8.2.98 🚀 Python-3.10.12 torch-2.4.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# Evaluate the model
metrics = model.val(data='/content/drive/MyDrive/yolov8/dataset/data.yaml')
# Out:
# Ultralytics YOLOv8.2.98 🚀 Python-3.10.12 torch-2.4.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/yolov8/dataset/labels/val.cache... 6 images, 0 backgrounds, 0 corrupt: 100%|██████████| 6/6 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:02<00:00,  2.48s/it]
#                    all          6          6    0.00454          1      0.541       0.34
#                 Normal          1          1   0.000838          1      0.332      0.232
#             suspicious          5          5    0.00824          1       0.75      0.447
# Speed: 2.7ms preprocess, 351.8ms inference, 0.0ms loss, 40.4ms postprocess per image
# Results saved to runs/detect/train2

# %%
# !ls /content/runs/detect/
# Out:
# train  train2

# %%
model.save('/content/drive/MyDrive/yolov8/trained_model.pt')

# %%
import cv2
from ultralytics import YOLO
import matplotlib.pyplot as plt

# Load the trained model
model = YOLO('/content/drive/MyDrive/yolov8/trained_model.pt')

# Path to a training image
train_image_path = '/content/drive/MyDrive/yolov8/dataset/images/train/applsci-13-08341-g001-550_jpg.rf.64b6de9c1e0245b0380160dda69e679c.jpg'

# Run inference
results = model(train_image_path, conf=0.25)  # Lower confidence threshold for testing

# Visualize results
annotated_frame = results[0].plot()

# Display the annotated image
plt.figure(figsize=(10, 10))
plt.imshow(cv2.cvtColor(annotated_frame, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# Print detection details
for result in results:
    boxes = result.boxes
    for box in boxes:
        cls_id = int(box.cls)
        cls_name = model.names[cls_id]
        conf = box.conf
        print(f"Detected {cls_name} with confidence {conf:.2f}")
# Out:
# image 1/1 /content/drive/MyDrive/yolov8/dataset/images/train/applsci-13-08341-g001-550_jpg.rf.64b6de9c1e0245b0380160dda69e679c.jpg: 640x640 (no detections), 244.7ms
# Speed: 5.4ms preprocess, 244.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)

# %%
# Load the trained model
model = YOLO('/content/drive/MyDrive/yolov8/trained_model.pt')

# Run inference on an image
results = model('/content/drive/MyDrive/yolov8/dataset/test_img_1.jpg')

# Check if results is a list of results
if isinstance(results, list):
    for result in results:
        result.show()  # Show each result
else:
    results.show()  # Show the result if it's a single object

# Optionally, save results if needed
#results.save()  # This saves the results to a directory3
# Out:
# image 1/1 /content/drive/MyDrive/yolov8/dataset/test_img_1.jpg: 640x640 (no detections), 1180.5ms
# Speed: 8.3ms preprocess, 1180.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
# Run inference with a lower confidence threshold
results = model('/content/drive/MyDrive/yolov8/dataset/test_img_1.jpg', conf=0.25)  # lower threshold to 25%
# Out:
# image 1/1 /content/drive/MyDrive/yolov8/dataset/test_img_1.jpg: 640x640 (no detections), 344.8ms
# Speed: 3.8ms preprocess, 344.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)

# %%
# Run inference
results = model('/content/drive/MyDrive/yolov8/dataset/test_img_1.jpg')

# Save the result image with bounding boxes (if any)
results[0].save('/content/drive/MyDrive/yolov8/dataset/test_img_1_result.jpg')
# Out:
# image 1/1 /content/drive/MyDrive/yolov8/dataset/test_img_1.jpg: 640x640 (no detections), 310.2ms
# Speed: 15.7ms preprocess, 310.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# '/content/drive/MyDrive/yolov8/dataset/test_img_1_result.jpg'

# %%
import cv2
from ultralytics import YOLO
import matplotlib.pyplot as plt

# Load the YOLO model (make sure the model path is correct)
model = YOLO('/content/drive/MyDrive/yolov8/trained_model.pt')

# Path to the image you want to test
image_path = '/content/drive/MyDrive/yolov8/dataset/test_img_1.jpg'

# Load the image using OpenCV
img = cv2.imread(image_path)

# Run prediction on the image
results = model(img)

# Visualize the results
annotated_img = results[0].plot()  # Annotate the image with bounding boxes

# Display the image with predictions
plt.imshow(cv2.cvtColor(annotated_img, cv2.COLOR_BGR2RGB))
plt.axis('off')  # Hide axes
plt.show()

# Print the prediction results
for r in results:
    print(f"Detected classes: {r.names}")
    print(f"Bounding boxes: {r.boxes.xyxy}")
    print(f"Confidence scores: {r.boxes.conf}")
# Out:
# 0: 640x640 1 person, 251.0ms
# Speed: 3.3ms preprocess, 251.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# ...
